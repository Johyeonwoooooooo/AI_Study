# %% [markdown]
# # Chpater5 : RNN

# %%
import numpy as np
class RNN:
    def __init__(self, Wx, Wh, b):
        self.param = [Wx, Wh, b]
        self.grad = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None
    
    def forward(self, x, h_prev):
        Wx, Wh, b = self.param
        t = np.matmul(h_prev, Wh) + np.matmul(x, Wx) + b
        h_next = np.tanh(t)

        self.cache = (x, h_prev, h_next)
        return h_next

    def backward(self, dh_next):
        Wx, Wh, b = self.param  
        x, h_prev = h_next = self.cache

        dt = dh_next * (1 - h_next**2)
        db = np.sum(dt, axis=0)
        dWh = np.matmul(h_prev.T, dt)
        dh_prev = np.matmul(dt, Wh.T)
        dWx = np.matmul(x.T, dt)
        dx = np.matmul(dt, Wx.T)

        self.grad[0][...] = dWx
        self.grad[1][...] = dWh
        self.grad[2][...] = db

        return dx, dh_prev

# %%
class TimeRNN:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.param = [Wx, Wh, b]
        self.grads = [np.zeros_like(param) for param in self.param]
        self.layers = None

        self.h, self.dh = None, None
        self.stateful = stateful

    def set_state(self, h):
        self.h = h

    def reset_state(self):
        self.h = None

    def forward(self, xs):
        Wx, Wh, b = self.param

        ''' 
        N = mini batch size
        T = data size (T개 분량의 시계열 데이터)
        D = data dimension
        '''
        N, T, D = xs.shape  
        '''
        D : weight dimension (data dimension)
        H : hidden weight size
        '''
        D, H = Wx.shape

        self.layers = []
        hs = np.empty((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')

        for t in range(T):
            layer = RNN(*self.param)
            self.h = layer.forward(xs[:, t, :], self.h)
            hs[:, t, :] = self.h
            self.layers.append(layer)

        return hs
    
    def backward(self, dhs):
        Wx, Wh, b = self.param
        N, T, H = dhs.shape
        D, H = Wx.shape

        dxs = np.empty((N, T, D), dtype='f')
        dh = 0
        grads = [0, 0, 0]

        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh)
            dxs[:, t, :] = dx

            for i, grad in enumerate(layer.grad):
                grads[i] += grad
        
        for i, grad in enumerate(grads):
            self.grads[i][...] = grad

        self.dh = dh

        return dxs

# %%
import sys
sys.path.append('..')
import numpy as np
from common.time_layers import *

class SimpleRnnlm:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        rnn_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        rnn_Wh = (rn(H, H) / np.sqrt(D)).astype('f')
        rnn_b = np.zeros(H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [TimeEmbedding(embed_W), TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
                       TimeAffine(affine_W, affine_b)]
        
        self.loss_layer = TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
        loss = self.loss_layer.forward(xs, ts)
        return loss
    
    def backward(self, dout = 1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        self.rnn_layer.reset_state()

# %% [markdown]
# ## RNNLM 학습 코드

# %%
import sys
sys.path.append('..')
import matplotlib.pyplot as plt
import numpy as np
from common.optimizer import SGD
from dataset import ptb

batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5
lr = 0.1
max_epoch = 100

corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]
ts = corpus[1:]
data_size = len(xs)
print(f"말뭉치 크기 : {corpus_size},   어휘 수 : {vocab_size}")

max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0
loss_count = 0
ppl_list = []

model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters):
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1
        
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1
    
    ppl = np.exp(total_loss / loss_count)
    print(f"| 에폭 {epoch + 1} , perplexity {ppl}")
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0
# Out:
# 말뭉치 크기 : 1000,   어휘 수 : 418
# | 에폭 1 , perplexity 377.1838508779789
# | 에폭 2 , perplexity 248.41963778498362
# | 에폭 3 , perplexity 219.53896145469284
# | 에폭 4 , perplexity 212.53428430255119
# | 에폭 5 , perplexity 204.92333790935206
# | 에폭 6 , perplexity 202.41113515864515
# | 에폭 7 , perplexity 199.0010460175723
# | 에폭 8 , perplexity 194.98270825856773
# | 에폭 9 , perplexity 190.20321188527535
# | 에폭 10 , perplexity 191.00752608845306
# | 에폭 11 , perplexity 186.66181380505128
# | 에폭 12 , perplexity 190.04259475959267
# | 에폭 13 , perplexity 188.39338783534814
# | 에폭 14 , perplexity 188.4868463734708
# | 에폭 15 , perplexity 189.21305962035618
# | 에폭 16 , perplexity 183.5586280617786
# | 에폭 17 , perplexity 182.61985194459777
# | 에폭 18 , perplexity 179.29996818135544
# | 에폭 19 , perplexity 180.33852287217786
# | 에폭 20 , perplexity 180.10099507513937
# | 에폭 21 , perplexity 178.9754762287921
# | 에폭 22 , perplexity 175.3916463026618
# | 에폭 23 , perplexity 172.36369338749287
# | 에폭 24 , perplexity 172.38193036629704
# | 에폭 25 , perplexity 171.0511718173298
# | 에폭 26 , perplexity 168.91332766885046
# | 에폭 27 , perplexity 163.65066324454256
# | 에폭 28 , perplexity 165.24384979920006
# | 에폭 29 , perplexity 158.33285307713433
# | 에폭 30 , perplexity 154.68112284623115
# | 에폭 31 , perplexity 154.67126975151882
# | 에폭 32 , perplexity 151.185990863702
# | 에폭 33 , perplexity 150.1311731188792
# | 에폭 34 , perplexity 143.68428455997548
# | 에폭 35 , perplexity 143.2036976889504
# | 에폭 36 , perplexity 135.24763501017145
# | 에폭 37 , perplexity 132.14812284435422
# | 에폭 38 , perplexity 128.13411707393433
# | 에폭 39 , perplexity 125.03660711160455
# | 에폭 40 , perplexity 116.96676013165485
# | 에폭 41 , perplexity 116.46122686579518
# | 에폭 42 , perplexity 110.49799210411928
# | 에폭 43 , perplexity 106.2112437561689
# | 에폭 44 , perplexity 101.31612472838036
# | 에폭 45 , perplexity 97.1491722021331
# | 에폭 46 , perplexity 95.5486390612599
# | 에폭 47 , perplexity 90.83276609285683
# | 에폭 48 , perplexity 84.84528892729801
# | 에폭 49 , perplexity 82.33039478440928
# | 에폭 50 , perplexity 78.61180933232728
# | 에폭 51 , perplexity 75.38267442610416
# | 에폭 52 , perplexity 72.55057909029449
# | 에폭 53 , perplexity 66.83593638751857
# | 에폭 54 , perplexity 65.31990375681991
# | 에폭 55 , perplexity 62.77045354417775
# | 에폭 56 , perplexity 58.10373616865958
# | 에폭 57 , perplexity 55.41329220964693
# | 에폭 58 , perplexity 51.663741614542644
# | 에폭 59 , perplexity 48.54328908561107
# | 에폭 60 , perplexity 46.73030693997285
# | 에폭 61 , perplexity 45.00856344095085
# | 에폭 62 , perplexity 41.94499396044885
# | 에폭 63 , perplexity 39.3476328480482
# | 에폭 64 , perplexity 36.96222395534098
# | 에폭 65 , perplexity 36.142387094342396
# | 에폭 66 , perplexity 33.95018205506756
# | 에폭 67 , perplexity 30.888177919482956
# | 에폭 68 , perplexity 29.29958225021049
# | 에폭 69 , perplexity 27.537708601073096
# | 에폭 70 , perplexity 26.789711953590928
# | 에폭 71 , perplexity 25.26458889351288
# | 에폭 72 , perplexity 23.202412737227537
# | 에폭 73 , perplexity 21.755392525245803
# | 에폭 74 , perplexity 21.21971036984796
# | 에폭 75 , perplexity 20.17883832480394
# | 에폭 76 , perplexity 17.923768923439624
# | 에폭 77 , perplexity 17.48748333279488
# | 에폭 78 , perplexity 15.997777247421139
# | 에폭 79 , perplexity 15.334314250189879
# | 에폭 80 , perplexity 14.61430631011294
# | 에폭 81 , perplexity 13.533218320770334
# | 에폭 82 , perplexity 13.767676916018138
# | 에폭 83 , perplexity 13.492411015372822
# | 에폭 84 , perplexity 11.990276397995038
# | 에폭 85 , perplexity 11.032166013744455
# | 에폭 86 , perplexity 11.114550271479576
# | 에폭 87 , perplexity 10.422264725610953
# | 에폭 88 , perplexity 9.672924027676766
# | 에폭 89 , perplexity 9.105814418853774
# | 에폭 90 , perplexity 8.873234251937635
# | 에폭 91 , perplexity 8.50906793685472
# | 에폭 92 , perplexity 7.934021925524854
# | 에폭 93 , perplexity 7.47559675705415
# | 에폭 94 , perplexity 6.959452031437564
# | 에폭 95 , perplexity 6.853737299683303
# | 에폭 96 , perplexity 6.282025658831759
# | 에폭 97 , perplexity 6.068401909453776
# | 에폭 98 , perplexity 5.860492677431687
# | 에폭 99 , perplexity 5.8793201141466005
# | 에폭 100 , perplexity 5.345631656007838

# %%
plt.plot(ppl_list)
plt.title("Training Perplexity")
# Out:
# Text(0.5, 1.0, 'Training Perplexity')

# %%
from common.trainer import RnnlmTrainer

model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
trainer = RnnlmTrainer(model, optimizer)

trainer.fit(xs, ts, max_epoch, batch_size, time_size)
# Out:
# | 에폭 1 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 416.49
# | 에폭 2 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 404.11
# | 에폭 3 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 308.08
# | 에폭 4 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 232.53
# | 에폭 5 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 216.00
# | 에폭 6 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 213.77
# | 에폭 7 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 203.08
# | 에폭 8 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 202.91
# | 에폭 9 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 196.58
# | 에폭 10 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 191.91
# | 에폭 11 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 193.01
# | 에폭 12 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 189.07
# | 에폭 13 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 192.94
# | 에폭 14 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 187.58
# | 에폭 15 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 187.46
# | 에폭 16 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 190.74
# | 에폭 17 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 188.77
# | 에폭 18 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 184.47
# | 에폭 19 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 180.23
# | 에폭 20 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 180.67
# | 에폭 21 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 177.52
# | 에폭 22 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 176.89
# | 에폭 23 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 178.07
# | 에폭 24 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 176.41
# | 에폭 25 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 169.33
# | 에폭 26 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 172.15
# | 에폭 27 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 168.59
# | 에폭 28 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 169.59
# | 에폭 29 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 162.49
# | 에폭 30 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 158.22
# | 에폭 31 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 157.75
# | 에폭 32 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 151.29
# | 에폭 33 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 149.31
# | 에폭 34 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 149.57
# | 에폭 35 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 142.49
# | 에폭 36 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 138.15
# | 에폭 37 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 137.70
# | 에폭 38 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 130.96
# | 에폭 39 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 126.42
# | 에폭 40 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 122.51
# | 에폭 41 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 114.86
# | 에폭 42 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 114.63
# | 에폭 43 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 109.84
# | 에폭 44 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 106.37
# | 에폭 45 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 96.40
# | 에폭 46 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 95.07
# | 에폭 47 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 95.41
# | 에폭 48 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 88.82
# | 에폭 49 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 84.67
# | 에폭 50 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 79.51
# | 에폭 51 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 76.17
# | 에폭 52 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 71.68
# | 에폭 53 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 69.31
# | 에폭 54 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 65.34
# | 에폭 55 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 62.75
# | 에폭 56 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 59.57
# | 에폭 57 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 57.56
# | 에폭 58 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 52.91
# | 에폭 59 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 50.60
# | 에폭 60 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 47.37
# | 에폭 61 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 44.40
# | 에폭 62 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 42.62
# | 에폭 63 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 40.84
# | 에폭 64 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 37.77
# | 에폭 65 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 35.05
# | 에폭 66 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 33.61
# | 에폭 67 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 31.87
# | 에폭 68 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 30.54
# | 에폭 69 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 28.22
# | 에폭 70 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 26.28
# | 에폭 71 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 25.26
# | 에폭 72 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 23.83
# | 에폭 73 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 22.46
# | 에폭 74 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 20.44
# | 에폭 75 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 20.32
# | 에폭 76 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 19.79
# | 에폭 77 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 18.38
# | 에폭 78 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 16.94
# | 에폭 79 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 16.51
# | 에폭 80 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 15.10
# | 에폭 81 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 14.69
# | 에폭 82 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 13.85
# | 에폭 83 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 12.97
# | 에폭 84 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 12.32
# | 에폭 85 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 11.49
# | 에폭 86 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 11.19
# | 에폭 87 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 10.34
# | 에폭 88 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 9.94
# | 에폭 89 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 9.87
# | 에폭 90 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 9.01
# | 에폭 91 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 8.75
# | 에폭 92 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 8.47
# | 에폭 93 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 7.74
# | 에폭 94 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 7.67
# | 에폭 95 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 7.01
# | 에폭 96 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 6.67
# | 에폭 97 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 6.23
# | 에폭 98 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 5.98
# | 에폭 99 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 5.93
# | 에폭 100 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 5.56
