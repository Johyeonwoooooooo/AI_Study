# %%
# %pip install transformers torch torchvision -q

# %%
import torch
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import requests

processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")
# Out:
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# config.json:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]

# %%
import matplotlib.pyplot as plt

url = "https://images.freeimages.com/clg/images/23/236873/snowman-sketch_f" 
image = Image.open(requests.get(url, stream=True).raw)

plt.imshow(image)
plt.axis('off')
plt.show()

inputs = processor(images=image, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a close up of a snowman with a fork and spoon

# %%
url = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1tzmOvLfKjVGhktFN6FTXB5ZPCKJMrw1N7Q&s"
image = Image.open(requests.get(url, stream=True).raw)

plt.imshow(image)
plt.axis('off')
plt.show()

inputs = processor(images=image, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a drawing of a computer with a keyboard and monitor

# %%
url = "https://image.yes24.com/images/chyes/sketch/20070903/6-2.jpg" 
image = Image.open(requests.get(url, stream=True).raw)

plt.imshow(image)
plt.axis('off') 
plt.show()

inputs = processor(images=image, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a drawing of a dog laying down on its back with its head down

# %%
url = "https://colormadehappy.com/wp-content/uploads/2022/11/Snowman-Drawing-2.jpg.webp"
image = Image.open(requests.get(url, stream=True).raw)

plt.imshow(image)
plt.axis('off')
plt.show()

inputs = processor(images=image, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a drawing of a snowman with a hat on it

# %%
url = "https://colormadehappy.com/wp-content/uploads/2022/11/Snowman-Drawing-3.jpg.webp"
image = Image.open(requests.get(url, stream=True).raw)

plt.imshow(image)
plt.axis('off')
plt.show()

inputs = processor(images=image, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a black and white drawing of a snowman wearing a hat

# %%
url = "https://colormadehappy.com/wp-content/uploads/2022/11/Snowman-Drawing-4.jpg.webp" 
image = Image.open(requests.get(url, stream=True).raw)

plt.imshow(image)
plt.axis('off') 
plt.show()

inputs = processor(images=image, return_tensors="pt")
out = model.generate(**inputs)
caption = processor.decode(out[0], skip_special_tokens=True)

print("Generated Caption:", caption)
# Out:
# Generated Caption: a black and white drawing of a snowman with a hat and mittens
