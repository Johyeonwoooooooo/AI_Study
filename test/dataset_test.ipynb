# %%
 # -*- coding: utf-8 -*-
import pandas as pd

data = pd.read_csv('TB_RECIPE_SEARCH-20231130.csv')

# %%
# print(data.columns)
data.head()
data.shape
# Out:
# (184991, 18)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
import numpy as np

def preprocess_data(series):
    ingredient_list = []
    for data in series:
        if pd.notnull(data):  # NaN이 아닌 경우에만 처리
            ingredients = data.split("|")
            recipe_list = []
            for ingredient in ingredients:
                ingredient = ingredient.replace("[재료]", "").strip()
                parts = ingredient.split()
                if len(parts) >= 1:
                    ingredient_name = " ".join(parts[:-1])  # 재료 이름 추출
                    recipe_list.append(ingredient_name)
            if recipe_list:  # 재료가 있는 경우에만 추가
                ingredient_list.append(" ".join(recipe_list))  # 리스트를 문자열로 변환하여 추가
    
    return ingredient_list


# 데이터 전처리
recipes = preprocess_data(data.loc[:100, "CKG_MTRL_CN"])
print(recipes)

num_samples = len(recipes)
num_clusters = 10

import gensim.downloader as api

# 사전 훈련된 Word2Vec 모델
word2vec_model = api.load('word2vec-google-news-300')

new_data = ['peanut', 'chicken']
embedded_data = []
for sentence in new_data:
    embedded_sentence = [word2vec_model[word] for word in sentence.split() if word in word2vec_model.key_to_index]
    if embedded_sentence:
        embedded_data.append(np.mean(embedded_sentence, axis=0))

# print(embedded_data)

# K-means 클러스터링 수행
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(embedded_data)

print(kmeans.predict(embedded_data))


# if num_samples >= num_clusters:
#     # 피처 벡터화
#     vectorizer = CountVectorizer()
#     X = vectorizer.fit_transform(recipes)

#     # K-means 클러스터링 수행
#     kmeans = KMeans(n_clusters=num_clusters, random_state=42)
#     kmeans.fit(X)

#     new_data = ['땅콩 닭고기 튀김가루']
#     transformed_data = vectorizer.transform(new_data)
#     print(kmeans.predict(transformed_data))

#     # 클러스터링 결과 확인
#     clustered_recipes = pd.DataFrame({"Recipe": recipes, "Cluster": kmeans.labels_})
#     print(clustered_recipes.loc[clustered_recipes.Cluster == 4, 'Recipe'])
# else:
#     print("Error: Number of samples is less than number of clusters.")
# Out:
# ['어묵 김밥용김 당면 양파 당근 깻잎 튀김가루 올리브유 간장 참기름', '두부 당근 고추 브로콜리 새우  계란', '밥 당근 치자단무지 신김치 무순 날치알 김가루  참기름 통깨 계란 노른자', '현미 찹쌀 호두 물 소금', '북어포 찹쌀가루 1C [양념] 간장 설탕 물 다진파 다진마늘 참기름 깨소금 후춧가루', '파스타면 [양념] 토마토 토마토 페이스트 양파 다진마늘 피망 올리브유', '건표고버섯 오이 당근 양파 사과 그외의 과일 [녹말물] 녹말가루 물 계란 노른자 1개 [탕수 소스] 물 설탕 식초 간장 녹말물', '닭 1마리 [닭양념] 통마늘 다진마늘   마늘솔트또는소금 [샐러드 드레싱] 파인애플 마요네즈 머스터드 식초1/2T(또는 꿀', '  달걀  물 ', '밥 참치캔 큰거   김밥용김 [양념]    ', '떡볶이떡 당근 파 양파 양배추 어묵    홍합살 [양념장] 고춧가루 고추장 물엿 간장 참기름 다진 마늘 깨 후추가루', '스팸 싱글 샌드위치용 토마토 상추 치즈 1장 [양념]  ', '밥 깻잎 참치 작은캔  조미 김10장 [양념] 다진   ', '새우 밥 김치 당근 감자 양파   ', '밥   밑반찬 [양념] 참기름 맛소금 깨', '밥 김치 베이컨 깻잎 양파', '식빵 스팸 오이 체다치즈(노란치즈) [양념]  ', '고구마 큰거 모차렐라치즈(피자치즈) 버터   달걀', '오징어 양파 대파 당근 청고추 홍고추 1개 [양념] 고추장 고춧가루 다진 마늘 참기름 설탕 간장 청주 후추 소금', '가래떡 호두 15알 정도 [양념] 깨 꿀', '새우 양파 김치     빵가루 [양념] 백세 카레가루', '블루베리 설탕 레몬즙 럼 모닝빵', '모닝빵 새우 상추 토마토 피클 마요네즈 [패티양념] 다진양파     ', '고구마 으깬것 생크림 설탕 버터  모짜렐라치즈 [커스타드크림] 우유 박력분 노른자 설탕 바닐라오일 버터', '국내산 제빵용 쌀가루 계란 우유 인스턴트 드라이 이스트 소금 버터 설탕 밤조림 아몬드 슬라이스 30그램. [쿠키반죽] 버터 설탕 노른자 박력분 바닐라오일', '고구마 생크림 버터 커스타드크림 설탕 소금 소금 설탕', '감자(中) 생크림 우유 양파 베이컨 체다치즈 피자치즈 약간 [양념] 버터 육수', '좋아하는 종류의 라면 김치 굴 파 청or홍고추 1개 [양념] 고춧가루', '감자 올리브유 베이컨 모짜렐라치즈 파슬리 약간 [양념] 소금', '양배추 숙주 오징어 새우 베이컨 계란 실파 약간 [오코노미야키반죽] 밀가루 물 혼다시 후추&소금 약간 [양념] ', '당면 부추 만두피 10장 [양념] 간장 물엿 또는 설탕 참기름 다진 파 다진 마늘 소금 후추', '손두부  소금 꽈리고추 양파 대파 1줄기 [양념장] 간장 물 설탕 물엿 or요리당 굴소스 고춧가루 마늘 후춧가루', '갈비 월계수잎 통마늘 후춧가루 청주 감자 양파 1개 [양념] 고춧가루 1컵(대략 간장 청량고추 통마늘 청주 설탕 생강가루 참기름 양파 파인애플 양겨자가루', '어묵 포도씨유 꽈리고추 양파 느타리버섯 대파 물 1/4컵 [양념] 간장 물 설탕 물엿 굴소스 고춧가루 마늘 후춧가루 통깨', '닭날개 재움용 우유 1컵 [허니머스타드소스] 머스타드 마요네즈 꿀 1큰술 [버팔로윙스 소스] 올리브유 버터 BBQ소스 A1소스 고운고춧가루 (or파프리카가루) 케첩 후춧가루 다진마늘 핫소스 파슬리 오레가노', '밥  오이   김 [양념] 참기름 맛소금', '홍시 또는 대봉시 큰것 생크림 300그램 [양념] 설탕 또는 꿀 레몬즙', '박력분 단호박가루 버터 슈가파우더 호박씨 바닐라오일 계란흰자 설탕', '박력분 버터 베이킹 파우더 베이킹 소다 계란 설탕 초코칩 유기농 초코 뮈슬리', '[타르트지 재료] 버터 박력분 소금 설탕 계란 1개 [아몬드크림] 버터 크림치즈 설탕 생크림 계란 아몬드가루 코코넛가루 바닐라 오일 럼주 견과류', '홍시 큰것 4~5개 [양념] 설탕 레몬즙 플레인 요거트', '강력분 우유 인스턴드 드라이 이스트 소금 설탕 레몬즙 버터 계란 꿀 각종 당절임 과일 럼주 1컵 토핑용 버터', '배추김치 김밥 속에 넣었던 소고기 체다치즈 스파게티 국수 모짜렐라 치즈 적당량 [양념] 헤비위핑크림', '돼지고기 아무부위나 감자 중간크기 양파 두부 1/2모 [양념] 고추장 된장  마늘 다진것 참기름', '박력분 버터 설탕 밤페이스트 장식용 밤조림 베이킹파우더 계란 우유 밤조림 바닐라오일', '닭 중간크기 청양고추 건고추 양파 감자 당면 대파 물 1컵 [닭 밑간] 생강즙 후춧가루 마늘 청주 1큰술 [양념장] 설탕 간장 캬라멜소스 청양고추 후춧가루 다진마늘 참기름', '브리오슈슬라이스(약간 두툼하게) 바나나 계란 우유 버터 베이컨 좋아하는 과일 [양념] 소금 시럽 슈거파우더', '단호박 작은크기 낙지 작은크기 모듬해물 칵테일 새우 양파 작은크기 파프리카 대파 떡볶이떡 피자치즈 200g [양념장] 고추장 고춧가루 굴소스 다진마늘 후춧가루 설탕 요리당', '앤젤헤어 파스타 명란 마늘 다진것 우메보시 1개 [양념] 참기름 시칠미', '박력분 코코아가루 다크초콜릿 버터 달걀 설탕 생크림 60g [데코레이션] ', '한우 우둔살 파프리카 피망 양파 큰것 새송이버섯 카놀라유 애호박 후춧가루 2 청주 허브솔트 A1소스 바베큐소스 2큰술 [볶음밥 ]  소금 카놀라유 굴소스', '바질잎 통마늘 잣 올리브오일 파마산치즈', '강력분 설탕 소금 몰트 양파 중간것 올리브 20개 올리브유 물 드라이이스트 8그램 (올리브유', '흑미가루 노른자 설탕 소금 바닐라오일 베이킹 파우더 우유 버터 흰자 설탕', '후랑크소세지(줄줄이비엔나) 파프리카 양파 큰것 당근 대파 올리브유 적당량 [양념] 굴소스 케찹 설탕 후춧가루', '식빵 양상추     후추   계란 다진양파', '[푸딩액 재료] 우유 설탕 계란 바닐라오일 2방울 [카라멜소스] 설탕 물', '감자 중간것 4개 [양념] 올리브유(or카놀라유) 소금 후춧가루 파슬리가루 다진마늘 1/2큰술 [소스]   ', '강력분 박력분 설탕 소금 베이킹 파우더 버터 건포도 달갈 우유 대추야자 씨뺀것 계란물', '떡볶이떡 400~500그램 양파 양배추 큰것 대파 어묵 쫄면 200그램 물 또는 육수 1+1/2컵 [양념] 다*다(소고기맛 조미료) 춘장 고추장 설탕 다진마늘', '고구마 중간것 생크림 적고구마가루 블럭모짜렐라치즈 100그램 [양념] 설탕', '찹쌀가루(습식) 찬물 바나나 중간것 옥수수전분 적당량 [양념] 팥앙금', '어묵 팽이버섯 쑥갓 당근 표고버섯 대파 1쪽 [카레육수] 물 백세카레가루 가쓰오부시장국', '박력분 버터 설탕 베이킹파우더 계란 우유 초코칩 40g [양념] 커피액기스 소금', '박력분 물 말린표고버섯 이스트 5g [양념] 설탕 소금 간장 참기름 올리브오일', '어묵 양배추 1/4통 [육수재료] 무 파 양파 건새우 다시마 청양고추 2개 [양념] 고춧가루 고추장 간장 설탕 물엿 다진마늘 청주 후추가루', ' 베이컨 양파 파프리카 파슬리 [양념] 생크림 치즈', '강력분 몰트 인스턴트 드라이이스트 카놀라유 라이트 미지근한 물 소금 설탕', '파니니 불고기 양념한것 닭가슴살 양상추 또는 로메인 토마토 중간것 양파 중간것 치즈 달걀 슬라이스햄 피클다진것 [양념]    ', '우유 생크림 500ml [양념] 레몬즙(1개분) 소금', '생크림 박력분 설탕 베이킹파우더 계란 1개 [양념] 포피씨드 레몬필 유자청', '박력분 버터 바닐라오일 아몬드파우더 소금 슈가파우더 베이킹파우더 시나몬파우더 1/2ts [양념] 장식용 슈가파우더', '바나나 으깬것 토핑용 바나나 버터 설탕 박력분 코코아가루 초코칩 베이킹 파우더 베이킹소다 생크림 바닐라오일', '박력분 버터 계란 설탕 애호박 우유 사워크림 베이킹 파우더 소금 바닐라오일  박력 버터 설탕', '다크커버춰 버터 박력분 코코아 흑설탕 계란 인스턴트 커피 깔루아 견과류', '백미가루 아몬드가루 슈가파우더 베이킹 파우더 바닐라가루 계란 흰자 트리몰린(물엿) 버터', '강력분 박력분 물 드라이 이스트 소금 설탕 버터 탈지분유 달걀 충전용 버터 달걀 물']
# [array([-2.30712891e-02, -5.41992188e-02,  1.70898438e-01,  4.98046875e-01,
#        -1.24511719e-01, -7.56835938e-03, -2.79296875e-01, -1.92382812e-01,
#        -1.22558594e-01,  1.19140625e-01,  3.51562500e-01, -1.43554688e-01,
#        -4.83398438e-02, -1.11816406e-01, -3.33984375e-01,  4.55078125e-01,
#        -5.07812500e-01,  7.81250000e-02, -2.67578125e-01,  8.34960938e-02,
#         2.05078125e-02,  4.05883789e-03,  1.19628906e-01, -1.15356445e-02,
#         2.08740234e-02,  1.88476562e-01,  6.59179688e-02, -1.31835938e-01,
#         1.80664062e-01,  1.58203125e-01, -1.81640625e-01,  1.46484375e-01,
#        -1.41601562e-01, -6.05468750e-02, -5.73730469e-02,  7.08007812e-02,
#         3.82812500e-01, -5.58471680e-03,  1.39648438e-01,  3.39355469e-02,
#         1.99218750e-01, -1.53320312e-01, -1.09375000e-01,  1.03515625e-01,
#        -8.54492188e-02, -3.16406250e-01, -1.01562500e-01,  7.12890625e-02,
#        -4.15039062e-02, -4.37011719e-02, -6.64062500e-02, -7.81250000e-03,
#         6.93359375e-02,  5.71289062e-02, -1.25976562e-01,  2.95410156e-02,
#        -2.18505859e-02, -1.65039062e-01, -1.87500000e-01, -9.47265625e-02,
#        -4.90722656e-02,  2.00195312e-01, -3.17382812e-02, -1.04980469e-01,
#         3.65234375e-01, -2.98828125e-01, -4.00390625e-01, -2.13623047e-02,
#        -7.03125000e-02, -3.63159180e-03,  9.52148438e-02, -3.53515625e-01,
#        -1.88446045e-03, -2.14843750e-01, -6.52343750e-01,  2.63671875e-02,
#        -5.05371094e-02, -4.16015625e-01,  6.49414062e-02, -1.08398438e-01,
#        -5.78125000e-01,  1.39648438e-01,  2.30468750e-01, -8.69140625e-02,
#         1.77001953e-02,  5.51757812e-02,  1.22680664e-02,  9.03320312e-02,
#        -3.14453125e-01, -1.58203125e-01, -5.41992188e-02, -1.24023438e-01,
#         3.73535156e-02, -2.23632812e-01,  8.44726562e-02,  1.98242188e-01,
#         8.30078125e-02,  2.31445312e-01, -4.49218750e-02,  1.18164062e-01,
#         1.02050781e-01, -4.07714844e-02, -1.43554688e-01, -5.59082031e-02,
#        -2.94921875e-01,  2.07031250e-01,  1.31835938e-01,  1.17675781e-01,
#        -6.40625000e-01, -8.83789062e-02, -9.91210938e-02, -9.86328125e-02,
#        -1.67968750e-01,  2.29492188e-01,  6.34765625e-02,  1.74804688e-01,
#         1.22070312e-01, -5.63964844e-02, -7.78198242e-03, -1.80664062e-01,
#        -2.05078125e-01,  1.97265625e-01,  2.01416016e-02, -9.86328125e-02,
#         3.75976562e-02, -5.12695312e-02,  1.73828125e-01,  5.17578125e-02,
#         1.57226562e-01, -1.41601562e-01, -4.64843750e-01,  8.20312500e-02,
#        -3.10546875e-01,  1.86523438e-01, -1.44531250e-01,  2.50000000e-01,
#         1.76757812e-01,  8.15429688e-02, -9.94873047e-03,  5.90820312e-02,
#        -1.78710938e-01, -5.24902344e-02, -3.08593750e-01, -1.55273438e-01,
#        -5.83496094e-02, -1.54296875e-01,  1.15234375e-01, -4.22363281e-02,
#        -2.35351562e-01,  3.68652344e-02, -1.25000000e-01, -2.24609375e-01,
#        -1.78710938e-01, -1.31835938e-02, -1.77734375e-01, -4.32128906e-02,
#         2.61230469e-02, -1.65039062e-01, -2.83203125e-01, -8.64257812e-02,
#        -1.78222656e-02,  1.80664062e-01,  1.82617188e-01,  5.85937500e-02,
#         1.78710938e-01,  1.55273438e-01, -7.22656250e-02,  3.73046875e-01,
#        -4.55078125e-01, -2.80761719e-02, -7.22656250e-02,  1.66015625e-01,
#         1.77001953e-03, -4.41406250e-01, -5.46875000e-02, -3.88671875e-01,
#         2.30468750e-01,  1.86523438e-01,  1.17187500e-01,  1.26953125e-01,
#        -1.05468750e-01, -1.94335938e-01, -3.89099121e-03,  1.46484375e-01,
#         5.63964844e-02,  2.79235840e-03, -1.81884766e-02, -3.44238281e-02,
#        -1.03027344e-01,  4.06250000e-01, -5.93261719e-02,  5.54199219e-02,
#         3.80859375e-02, -2.38281250e-01,  1.12792969e-01,  4.60937500e-01,
#         2.09960938e-02, -3.53515625e-01, -2.63671875e-01, -1.27929688e-01,
#         1.68945312e-01, -3.61328125e-01,  5.98144531e-03, -3.30078125e-01,
#         5.07812500e-02, -1.40625000e-01,  4.21875000e-01, -6.29882812e-02,
#         8.74023438e-02, -1.62109375e-01, -1.58203125e-01,  1.04003906e-01,
#        -2.62451172e-02,  1.59179688e-01,  2.55859375e-01,  2.12890625e-01,
#        -1.33789062e-01,  3.05175781e-02,  6.64062500e-02,  1.48437500e-01,
#        -9.17968750e-02, -3.12500000e-02,  2.26562500e-01,  1.44042969e-02,
#         2.92968750e-01,  4.02832031e-03,  6.25610352e-04,  5.51757812e-02,
#         1.33789062e-01, -2.79296875e-01,  3.35937500e-01,  2.63671875e-02,
#        -1.26953125e-01,  6.64062500e-02, -5.39062500e-01, -2.06054688e-01,
#         2.61718750e-01,  8.42285156e-03,  5.12695312e-02,  8.20312500e-02,
#         3.35937500e-01, -2.13867188e-01, -3.39355469e-02, -3.37890625e-01,
#        -3.68652344e-02, -1.89453125e-01, -3.80859375e-01,  5.56640625e-02,
#         3.47656250e-01,  1.29882812e-01, -3.02734375e-01, -3.96484375e-01,
#         3.37890625e-01, -3.35937500e-01,  5.34667969e-02, -3.06640625e-01,
#        -1.28906250e-01, -1.60156250e-01, -7.66601562e-02, -1.94335938e-01,
#        -1.34887695e-02,  3.55468750e-01, -4.68750000e-01,  3.76953125e-01,
#         2.36328125e-01, -2.55126953e-02, -2.71484375e-01,  1.19140625e-01,
#        -2.46093750e-01, -2.11914062e-01,  3.11279297e-02,  3.61328125e-01,
#        -2.74658203e-02, -4.45312500e-01, -2.26562500e-01, -1.85546875e-01,
#        -3.18359375e-01, -2.07031250e-01,  9.53674316e-04,  8.85009766e-03,
#        -3.36914062e-02,  2.84423828e-02,  1.67846680e-03, -1.01562500e-01,
#        -4.98046875e-01, -2.81250000e-01, -4.60937500e-01,  1.98242188e-01,
#         5.56640625e-02,  2.47070312e-01, -4.82421875e-01, -3.32031250e-02,
#         3.06640625e-01, -1.49414062e-01,  3.57421875e-01, -1.07910156e-01,
#         9.32617188e-02,  6.25000000e-01, -1.28173828e-02,  9.22851562e-02],
#       dtype=float32), array([-0.13476562, -0.02404785,  0.04418945,  0.27539062, -0.03271484,
#         0.13183594,  0.17382812, -0.00095367, -0.0625    ,  0.20996094,
#        -0.03051758, -0.3046875 , -0.10742188, -0.08203125, -0.43359375,
#         0.03637695, -0.11474609,  0.01092529, -0.34375   , -0.02929688,
#         0.30273438, -0.08203125,  0.22265625,  0.11083984, -0.14257812,
#        -0.04443359, -0.01745605,  0.01531982,  0.0018692 ,  0.23828125,
#        -0.26367188, -0.15136719,  0.13183594, -0.12792969,  0.0703125 ,
#         0.24609375,  0.17871094,  0.12353516,  0.06396484,  0.265625  ,
#        -0.12158203, -0.22558594,  0.13867188,  0.125     , -0.03588867,
#        -0.20019531, -0.08837891, -0.00234985,  0.20703125,  0.21679688,
#        -0.12695312,  0.23730469,  0.0234375 ,  0.1328125 , -0.06835938,
#        -0.09179688,  0.17089844, -0.07617188,  0.22070312,  0.03735352,
#        -0.04492188,  0.20410156, -0.12011719, -0.00543213,  0.23632812,
#        -0.28125   , -0.1484375 , -0.07373047,  0.21972656, -0.08007812,
#         0.41210938, -0.0625    ,  0.03149414, -0.03271484, -0.09912109,
#        -0.25585938, -0.14941406, -0.28710938, -0.04956055, -0.33203125,
#         0.10400391, -0.03369141,  0.24609375, -0.00848389,  0.10986328,
#        -0.00634766, -0.28125   ,  0.28515625, -0.11035156, -0.31054688,
#        -0.20898438,  0.05566406, -0.21386719, -0.40039062, -0.18359375,
#        -0.265625  , -0.0534668 , -0.02148438, -0.1171875 , -0.20117188,
#        -0.05639648, -0.11767578, -0.12109375, -0.05859375, -0.0234375 ,
#        -0.09863281,  0.35351562, -0.13476562,  0.03063965, -0.07177734,
#        -0.15527344, -0.27929688,  0.02026367,  0.26953125, -0.24121094,
#        -0.00558472, -0.01879883, -0.17382812, -0.27148438, -0.11865234,
#        -0.05981445, -0.10986328, -0.16113281, -0.10253906, -0.20605469,
#        -0.08935547,  0.10107422,  0.01074219,  0.12890625,  0.12158203,
#        -0.4453125 ,  0.1640625 , -0.08984375,  0.15917969, -0.13085938,
#         0.203125  ,  0.02282715,  0.07177734,  0.31054688,  0.00215149,
#        -0.07128906, -0.12695312,  0.15917969,  0.23242188,  0.07470703,
#        -0.06103516, -0.20507812, -0.05981445, -0.16796875,  0.12597656,
#         0.06347656, -0.19140625, -0.12353516,  0.08496094,  0.02197266,
#        -0.1484375 , -0.12597656, -0.21386719, -0.27539062, -0.08105469,
#        -0.2578125 ,  0.00241089,  0.20410156,  0.06396484, -0.17382812,
#         0.01806641,  0.11376953, -0.03393555,  0.17578125,  0.06689453,
#        -0.296875  ,  0.10449219,  0.0291748 , -0.1328125 ,  0.0213623 ,
#        -0.18847656,  0.09130859,  0.05932617,  0.109375  ,  0.30859375,
#        -0.03344727, -0.2890625 , -0.09863281, -0.11328125,  0.21972656,
#        -0.05957031,  0.05102539,  0.16210938, -0.16503906,  0.25195312,
#        -0.10839844,  0.15820312, -0.06494141, -0.09326172,  0.12792969,
#         0.38867188, -0.22851562, -0.05883789, -0.13085938,  0.02380371,
#         0.09912109, -0.24316406, -0.04394531, -0.09228516, -0.09863281,
#        -0.10888672,  0.125     , -0.07421875,  0.17871094, -0.06835938,
#        -0.1953125 ,  0.2890625 ,  0.0189209 , -0.0390625 ,  0.08349609,
#         0.06079102,  0.03540039, -0.03637695,  0.04345703,  0.14160156,
#        -0.078125  , -0.02026367, -0.10888672, -0.09765625,  0.4140625 ,
#        -0.10253906,  0.01757812,  0.19726562,  0.09375   ,  0.15234375,
#         0.27929688, -0.265625  ,  0.08007812,  0.21582031, -0.09033203,
#        -0.51171875,  0.23632812, -0.01226807, -0.13769531,  0.24023438,
#         0.16992188,  0.08251953, -0.03808594,  0.07714844, -0.01818848,
#        -0.33984375,  0.07324219,  0.09277344,  0.16210938,  0.21972656,
#        -0.00613403,  0.10302734,  0.13085938, -0.12451172,  0.296875  ,
#        -0.27734375,  0.10595703,  0.11523438,  0.03466797, -0.06689453,
#         0.10595703,  0.20117188,  0.09570312, -0.07421875,  0.13378906,
#        -0.10351562, -0.15039062, -0.04125977, -0.00056076,  0.07128906,
#         0.10498047,  0.140625  ,  0.11035156, -0.328125  ,  0.11474609,
#        -0.24121094, -0.0559082 ,  0.01721191,  0.04907227,  0.06738281,
#        -0.05981445,  0.10009766,  0.09277344,  0.02636719, -0.16113281,
#        -0.10498047, -0.09228516,  0.33789062, -0.08398438,  0.35546875,
#        -0.2109375 , -0.04125977, -0.29492188,  0.30273438,  0.18457031,
#        -0.07226562,  0.0612793 ,  0.1015625 ,  0.06689453,  0.10107422],
#       dtype=float32)]

# %%
print(len(embedded_data))
# Out:
# 2

# %% [markdown]
# pip install transformers
#
# pip install konlpy
#
# pip install torch torchvision torchaudio 필수
#
# JAVA가 환경변수로 등록되어 있어야 함

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from konlpy.tag import Okt

# KoBERT 모델 로드
tokenizer = AutoTokenizer.from_pretrained("klue/bert-base")
model = AutoModelForSequenceClassification.from_pretrained("klue/bert-base")

# Konlpy 형태소 분석기 초기화
okt = Okt()

# 뉴스 기사 본문 입력
text = """
    파이썬에는 NLP 관련 도구가 정말 많다. 원하는 텍스트 분석 작업에 적절한 파이썬 라이브러리는 어떻게 찾을 수 있을까? 용도별 추천 라이브러리와 장단점을 살펴본다. 

NLP(Natural Language Processing, 자연어 처리)는 ‘음성 및 텍스트를 위한 AI’라고 말할 수 있다. 음성 명령, 음성 및 텍스트 번역, 감성 분석, 텍스트 요약, 언어와 관련된 여타 많은 애플리케이션은 그 동안 크게 개선됐다. 분석에 사용되는 NLP의 성능 또한 딥러닝을 통해 획기적으로 향상됐다.

파이썬 언어는 NLP를 포함한 모든 종류의 머신러닝에 유용한 프론트엔드를 제공한다. 하지만 파이썬 생태계에는 고를 NLP가 너무 많아 당황스러운 것도 사실이다. 여기서는 주요 파이썬용 라이브러리의 사용례와 장단점 그리고 인기도를 살펴본다. 
 
CoreNLP
스탠포드 대학(Stanford University)이 만든 CoreNLP 라이브러리는 NLP 예측 및 분석 작업을 대규모로 수행할 수 있게 해주는 실용 단계의 NLP 솔루션이다. CoreNLP는 자바(Java)로 작성됐지만, 이를 위한 API와 여러 파이썬 패키지가 등장해 있는 상태다. Stanza로 불리는 네이티브 NLP 라이브러리가 그 중 하나다.

"""

# 형태소 분석 및 품사 태깅
nouns = []
for token in okt.pos(text):
    # 명사만 추출
    if token[1] in ["Noun", "Alpha"]:
        nouns.append(token[0])

# KoBERT 모델을 이용한 핵심 단어 추출
inputs = tokenizer(" ".join(nouns), return_tensors="pt")
outputs = model(**inputs)
predictions = outputs.logits.argmax(dim=-1)

# 단어 빈도 계산
word_counts = {}
for word in nouns:
    word_counts[word] = word_counts.get(word, 0) + 1

# 결과 출력
for word, count in sorted(word_counts.items(), key=lambda x: -x[1]):
    print(f"{word}: {count}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at klue/bert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# NLP: 8
# 파이썬: 6
# 라이브러리: 5
# 텍스트: 4
# 분석: 4
# 수: 3
# 음성: 3
# 및: 3
# CoreNLP: 3
# 관련: 2
# 작업: 2
# 장단점: 2
# 위: 2
# 언어: 2
# 그: 2
# 러닝: 2
# 로: 2
# 도구: 1
# 정말: 1
# 용도: 1
# 별: 1
# 추천: 1
# Natural: 1
# Language: 1
# Processing: 1
# 자연어: 1
# 처리: 1
# AI: 1
# 말: 1
# 명령: 1
# 번역: 1
# 감성: 1
# 요약: 1
# 여타: 1
# 애플리케이션: 1
# 동안: 1
# 크게: 1
# 개선: 1
# 사용: 1
# 의: 1
# 성능: 1
# 또한: 1
# 딥: 1
# 통해: 1
# 획기: 1
# 향상: 1
# 를: 1
# 포함: 1
# 모든: 1
# 종류: 1
# 머신: 1
# 프론트엔드: 1
# 제공: 1
# 생태계: 1
# 당황: 1
# 것: 1
# 사실: 1
# 여기: 1
# 주요: 1
# 용: 1
# 용례: 1
# 인기: 1
# 스탠포드: 1
# 대학: 1
# Stanford: 1
# University: 1
# 이: 1
# 예측: 1
# 대규모: 1
# 수행: 1
# 실용: 1
# 단계: 1
# 솔루션: 1
# 자바: 1
# Java: 1
# 작성: 1
# API: 1
# 여러: 1
# 패키지: 1
# 등장: 1
# 상태: 1
# Stanza: 1
# 네이티: 1
# 브: 1
# 중: 1
# 하나: 1

# %%
import torch
import torchvision
import torchaudio

print(f"PyTorch 버전: {torch.__version__}")
print(f"Torchvision 버전: {torchvision.__version__}")
print(f"Torchaudio 버전: {torchaudio.__version__}")
# Out:
# PyTorch 버전: 2.2.2+cpu
# Torchvision 버전: 0.17.2+cpu
# Torchaudio 버전: 2.2.2+cpu

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# KoBERT 모델 로드
tokenizer = AutoTokenizer.from_pretrained("klue/bert-base")
model = AutoModelForSequenceClassification.from_pretrained("klue/bert-base")

# 토큰화 및 모델 입력 준비
inputs = []
for index, row in data.iterrows():
    text = " ".join(row.dropna())  # NaN 값 제거 후 단어들을 하나의 문자열로 결합
    inputs.append(tokenizer(text, return_tensors="pt"))

# 모델에 입력하고 예측 수행
outputs = []
for input_data in inputs:
    output = model(**input_data)
    outputs.append(output)

# 결과 출력
for output in outputs:
    predictions = output.logits.argmax(dim=-1)
    print(predictions)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at klue/bert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#      10 inputs = []
#      11 for index, row in data.iterrows():
# ---> 12     text = " ".join(row.dropna())  # NaN 값 제거 후 단어들을 하나의 문자열로 결합
#      13     inputs.append(tokenizer(text, return_tensors="pt"))
#      15 # 모델에 입력하고 예측 수행
#
# TypeError: sequence item 0: expected str instance, int found
